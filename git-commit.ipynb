# %%
import os
from google.colab import drive
drive.mount('/content/drive')

os.chdir('/content/drive/MyDrive/Colab Notebooks/Deep Learning/DeepLearningWithPytorch')
# !pwd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Colab Notebooks/Deep Learning/DeepLearningWithPytorch

# %%
# !ls
# Out:
# git-commit.ipynb  README.md

# %%
#!git config --global user.email 'lunaman1@naver.com'
#!git config --global user.name 'DeuklyoungKo'

# !git add .
# !git commit -m 'git test'
# !git push
# Out:
# [main a9dab7c] git test
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite git-commit.ipynb (71%)
# To https://github.com/DeuklyoungKo/DeepLearningWithPytorch.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://DeuklyoungKo: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@github.com/DeuklyoungKo/DeepLearningWithPytorch.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.
